# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.distance import geodesic

# %%
def get_latlon(address):

    geolocator = Nominatim(user_agent="Property Distance Tracker")
    location = geolocator.geocode(address)
    if location is not None:
        return [location.latitude, location.longitude], str(location).split(",")[1]
    else:
        return -1, -1

# %%
with open("data/location_text/high_schools.txt", 'r') as f:
    content = f.read().splitlines()
    for location in content:
        print(get_latlon(location)[0])
# Out:
# Yule Brook College, 61, Dellar Road, Maddington, City Of Gosnells, Western Australia, 6109, Australia
# [-32.0481026, 116.00750806410974]
# Yanchep Secondary College, 21, Ravensbourne Street, Yanchep, City Of Wanneroo, Western Australia, 6035, Australia
# [-31.55264455, 115.64282481579346]
# Woodvale Secondary College, 110, Woodvale Drive, Woodvale, Joondalup, City Of Joondalup, Western Australia, 6026, Australia
# [-31.791755000000002, 115.79946773929777]
# Willetton Senior High School, Pinetree Gully Road, Willetton, City Of Canning, Western Australia, 6155, Australia
# [-32.0613041, 115.8791906142475]
# Warwick Senior High School, 355, Erindale Road, Warwick, Joondalup, City Of Joondalup, Western Australia, 6024, Australia
# [-31.83879985, 115.81597149471983]
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ...
